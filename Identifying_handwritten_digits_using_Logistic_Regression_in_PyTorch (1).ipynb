# %%
import torch
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable

# %%
# Set the batch size
batch_size = 64

# MNIST Dataset (Images and Labels)
train_dataset = dsets.MNIST(root ='./data',
                            train = True,
                            transform = transforms.ToTensor(),
                            download = True)

test_dataset = dsets.MNIST(root ='./data',
                           train = False,
                           transform = transforms.ToTensor())

# Dataset Loader (Input Pipeline)
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = batch_size,
                                          shuffle = False)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 6.08MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 160kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.52MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.99MB/s]

# %%
# Hyper Parameters
input_size = 784
num_classes = 10
num_epochs = 5
batch_size = 100
learning_rate = 0.001

# %%
class LogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(input_size, num_classes)

    def forward(self, x):
        out = self.linear(x)
        return out

# %%
model = LogisticRegression(input_size, num_classes)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

# %%
# Training the Model
for epoch in range(num_epochs):
	for i, (images, labels) in enumerate(train_loader):
		images = Variable(images.view(-1, 28 * 28))
		labels = Variable(labels)

		# Forward + Backward + Optimize
		optimizer.zero_grad()
		outputs = model(images)
		loss = criterion(outputs, labels)
		loss.backward()
		optimizer.step()

		if (i + 1) % 100 == 0:
			print('Epoch: [% d/% d], Step: [% d/% d], Loss: %.4f'
				% (epoch + 1, num_epochs, i + 1,
					len(train_dataset) // batch_size, loss.item())) # Use loss.item() to get the scalar value
# Out:
# Epoch: [ 1/ 5], Step: [ 100/ 600], Loss: 2.2653
# Epoch: [ 1/ 5], Step: [ 200/ 600], Loss: 2.1316
# Epoch: [ 1/ 5], Step: [ 300/ 600], Loss: 2.0728
# Epoch: [ 1/ 5], Step: [ 400/ 600], Loss: 2.0502
# Epoch: [ 1/ 5], Step: [ 500/ 600], Loss: 1.8755
# Epoch: [ 1/ 5], Step: [ 600/ 600], Loss: 1.8417
# Epoch: [ 1/ 5], Step: [ 700/ 600], Loss: 1.7914
# Epoch: [ 1/ 5], Step: [ 800/ 600], Loss: 1.7740
# Epoch: [ 1/ 5], Step: [ 900/ 600], Loss: 1.6303
# Epoch: [ 2/ 5], Step: [ 100/ 600], Loss: 1.6219
# Epoch: [ 2/ 5], Step: [ 200/ 600], Loss: 1.4747
# Epoch: [ 2/ 5], Step: [ 300/ 600], Loss: 1.4696
# Epoch: [ 2/ 5], Step: [ 400/ 600], Loss: 1.4522
# Epoch: [ 2/ 5], Step: [ 500/ 600], Loss: 1.4077
# Epoch: [ 2/ 5], Step: [ 600/ 600], Loss: 1.3378
# Epoch: [ 2/ 5], Step: [ 700/ 600], Loss: 1.3682
# Epoch: [ 2/ 5], Step: [ 800/ 600], Loss: 1.2565
# Epoch: [ 2/ 5], Step: [ 900/ 600], Loss: 1.1964
# Epoch: [ 3/ 5], Step: [ 100/ 600], Loss: 1.1848
# Epoch: [ 3/ 5], Step: [ 200/ 600], Loss: 1.2120
# Epoch: [ 3/ 5], Step: [ 300/ 600], Loss: 1.3227
# Epoch: [ 3/ 5], Step: [ 400/ 600], Loss: 1.1983
# Epoch: [ 3/ 5], Step: [ 500/ 600], Loss: 1.1885
# Epoch: [ 3/ 5], Step: [ 600/ 600], Loss: 1.2008
# Epoch: [ 3/ 5], Step: [ 700/ 600], Loss: 1.1464
# Epoch: [ 3/ 5], Step: [ 800/ 600], Loss: 1.0525
# Epoch: [ 3/ 5], Step: [ 900/ 600], Loss: 1.1394
# Epoch: [ 4/ 5], Step: [ 100/ 600], Loss: 1.0195
# Epoch: [ 4/ 5], Step: [ 200/ 600], Loss: 1.1086
# Epoch: [ 4/ 5], Step: [ 300/ 600], Loss: 0.9944
# Epoch: [ 4/ 5], Step: [ 400/ 600], Loss: 0.9924
# Epoch: [ 4/ 5], Step: [ 500/ 600], Loss: 0.9492
# Epoch: [ 4/ 5], Step: [ 600/ 600], Loss: 0.9626
# Epoch: [ 4/ 5], Step: [ 700/ 600], Loss: 1.0033
# Epoch: [ 4/ 5], Step: [ 800/ 600], Loss: 0.8807
# Epoch: [ 4/ 5], Step: [ 900/ 600], Loss: 0.9125
# Epoch: [ 5/ 5], Step: [ 100/ 600], Loss: 0.8341
# Epoch: [ 5/ 5], Step: [ 200/ 600], Loss: 0.8210
# Epoch: [ 5/ 5], Step: [ 300/ 600], Loss: 0.8692
# Epoch: [ 5/ 5], Step: [ 400/ 600], Loss: 0.9070
# Epoch: [ 5/ 5], Step: [ 500/ 600], Loss: 0.6673
# Epoch: [ 5/ 5], Step: [ 600/ 600], Loss: 0.7673
# Epoch: [ 5/ 5], Step: [ 700/ 600], Loss: 0.8092
# Epoch: [ 5/ 5], Step: [ 800/ 600], Loss: 0.8993
# Epoch: [ 5/ 5], Step: [ 900/ 600], Loss: 0.7834

# %%
# Test the Model
correct = 0
total = 0
for images, labels in test_loader:
    images = Variable(images.view(-1, 28 * 28))
    outputs = model(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum()

print('Accuracy of the model on the 10000 test images: % d %%' % (
            100 * correct / total))
# Out:
# Accuracy of the model on the 10000 test images:  84 %

# %%
import torch
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable


# MNIST Dataset (Images and Labels)
train_dataset = dsets.MNIST(root ='./data',
							train = True,
							transform = transforms.ToTensor(),
							download = True)

test_dataset = dsets.MNIST(root ='./data',
						train = False,
						transform = transforms.ToTensor())

# Dataset Loader (Input Pipeline)
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
										batch_size = batch_size,
										shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
										batch_size = batch_size,
										shuffle = False)

# Hyper Parameters
input_size = 784
num_classes = 10
num_epochs = 5
batch_size = 100
learning_rate = 0.001

# Model
class LogisticRegression(nn.Module):
	def __init__(self, input_size, num_classes):
		super(LogisticRegression, self).__init__()
		self.linear = nn.Linear(input_size, num_classes)

	def forward(self, x):
		out = self.linear(x)
		return out


model = LogisticRegression(input_size, num_classes)

# Loss and Optimizer
# Softmax is internally computed.
# Set parameters to be updated.
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

# Training the Model
for epoch in range(num_epochs):
	for i, (images, labels) in enumerate(train_loader):
		images = Variable(images.view(-1, 28 * 28))
		labels = Variable(labels)

		# Forward + Backward + Optimize
		optimizer.zero_grad()
		outputs = model(images)
		loss = criterion(outputs, labels)
		loss.backward()
		optimizer.step()

		if (i + 1) % 100 == 0:
			print('Epoch: [% d/% d], Step: [% d/% d], Loss: %.4f'
				% (epoch + 1, num_epochs, i + 1,
					len(train_dataset) // batch_size, loss.item()))

# Test the Model
correct = 0
total = 0
for images, labels in test_loader:
	images = Variable(images.view(-1, 28 * 28))
	outputs = model(images)
	_, predicted = torch.max(outputs.data, 1)
	total += labels.size(0)
	correct += (predicted == labels).sum()

print('Accuracy of the model on the 10000 test images: % d %%' % (
			100 * correct / total))
# Out:
# Epoch: [ 1/ 5], Step: [ 100/ 600], Loss: 2.1705
# Epoch: [ 1/ 5], Step: [ 200/ 600], Loss: 2.1013
# Epoch: [ 1/ 5], Step: [ 300/ 600], Loss: 1.9938
# Epoch: [ 1/ 5], Step: [ 400/ 600], Loss: 1.8835
# Epoch: [ 1/ 5], Step: [ 500/ 600], Loss: 1.8005
# Epoch: [ 1/ 5], Step: [ 600/ 600], Loss: 1.7116
# Epoch: [ 2/ 5], Step: [ 100/ 600], Loss: 1.7023
# Epoch: [ 2/ 5], Step: [ 200/ 600], Loss: 1.6562
# Epoch: [ 2/ 5], Step: [ 300/ 600], Loss: 1.5967
# Epoch: [ 2/ 5], Step: [ 400/ 600], Loss: 1.4925
# Epoch: [ 2/ 5], Step: [ 500/ 600], Loss: 1.4289
# Epoch: [ 2/ 5], Step: [ 600/ 600], Loss: 1.5325
# Epoch: [ 3/ 5], Step: [ 100/ 600], Loss: 1.4900
# Epoch: [ 3/ 5], Step: [ 200/ 600], Loss: 1.3639
# Epoch: [ 3/ 5], Step: [ 300/ 600], Loss: 1.3481
# Epoch: [ 3/ 5], Step: [ 400/ 600], Loss: 1.2721
# Epoch: [ 3/ 5], Step: [ 500/ 600], Loss: 1.2639
# Epoch: [ 3/ 5], Step: [ 600/ 600], Loss: 1.2521
# Epoch: [ 4/ 5], Step: [ 100/ 600], Loss: 1.2041
# Epoch: [ 4/ 5], Step: [ 200/ 600], Loss: 1.2538
# Epoch: [ 4/ 5], Step: [ 300/ 600], Loss: 1.0957
# Epoch: [ 4/ 5], Step: [ 400/ 600], Loss: 1.1529
# Epoch: [ 4/ 5], Step: [ 500/ 600], Loss: 1.0785
# Epoch: [ 4/ 5], Step: [ 600/ 600], Loss: 1.0892
# Epoch: [ 5/ 5], Step: [ 100/ 600], Loss: 1.0592
# Epoch: [ 5/ 5], Step: [ 200/ 600], Loss: 1.0504
# Epoch: [ 5/ 5], Step: [ 300/ 600], Loss: 1.0976
# Epoch: [ 5/ 5], Step: [ 400/ 600], Loss: 0.9778
# Epoch: [ 5/ 5], Step: [ 500/ 600], Loss: 0.9197
# Epoch: [ 5/ 5], Step: [ 600/ 600], Loss: 0.9420
# Accuracy of the model on the 10000 test images:  82 %
